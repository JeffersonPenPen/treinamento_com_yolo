# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/coco-yolo /content/datasets

# %%
# !git clone https://github.com/ultralytics/yolov5 /content/yolov5

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/datasets/dataset.yaml --weights yolov5s.pt --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-08-28 17:48:15.688973: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756403295.708854    6135 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756403295.714734    6135 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756403295.729643    6135 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !zip -r /content/resultados_treinamento.zip /content/yolov5/runs/
# Out:
# updating: content/yolov5/runs/train/exp5/ (stored 0%)
# updating: content/yolov5/runs/train/exp5/PR_curve.png (deflated 17%)
# updating: content/yolov5/runs/train/exp5/labels_correlogram.jpg (deflated 37%)
# updating: content/yolov5/runs/train/exp5/val_batch2_labels.jpg (deflated 6%)
# updating: content/yolov5/runs/train/exp5/weights/ (stored 0%)
# updating: content/yolov5/runs/train/exp5/weights/best.pt (deflated 9%)
# updating: content/yolov5/runs/train/exp5/weights/last.pt (deflated 9%)
# updating: content/yolov5/runs/train/exp5/labels.jpg (deflated 19%)
# updating: content/yolov5/runs/train/exp5/opt.yaml (deflated 50%)
# updating: content/yolov5/runs/train/exp5/events.out.tfevents.1756403302.f690032f3cbc.6135.0 (deflated 35%)
# updating: content/yolov5/runs/train/exp5/R_curve.png (deflated 12%)
# updating: content/yolov5/runs/train/exp5/train_batch0.jpg (deflated 3%)
# updating: content/yolov5/runs/train/exp5/val_batch0_pred.jpg (deflated 10%)
# ...

# %%
# !cp /content/resultados_treinamento.zip /content/drive/MyDrive/

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp5/weights/best.pt --source /content/yolov5/data/images/bus.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp5/weights/best.pt'], source=/content/yolov5/data/images/bus.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/data/images/bus.jpg: 640x480 3 persons, 31.0ms
# Speed: 0.5ms pre-process, 31.0ms inference, 67.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
# !python /content/yolov5/val.py --weights /content/yolov5/runs/train/exp5/weights/best.pt --data /content/datasets/dataset.yaml --img 640
# Out:
# val: data=/content/datasets/dataset.yaml, weights=['/content/yolov5/runs/train/exp5/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/datasets/labels/train.cache... 500 images, 0 backgrounds, 0 corrupt: 100% 500/500 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 16/16 [00:07<00:00,  2.06it/s]
#                    all        500       2258      0.972      0.918      0.967      0.758
# ...
